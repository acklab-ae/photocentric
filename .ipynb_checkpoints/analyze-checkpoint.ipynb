# %% [markdown]
# # Photo Analyzer
# - Author: Andrew Eng
# - Base Code: https://github.com/dingkeyan93/Intrinsic-Image-Popularity
# - Fork: https://github.com/acklab-ae/Intrinsic-Image-Popularity

# %%
import argparse
import torch
import torchvision.models
import torchvision.transforms as transforms
from PIL import Image
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
import os

# %% [markdown]
# # Rank photos

# %% [markdown]
# The following code was modified to take in a folder of pictures and process them vs. doing it one by one.

# %%
def prepare_image(image):

    if image.mode != 'RGB':
        image = image.convert("RGB")
    Transform = transforms.Compose([
            transforms.Resize([224,224]),      
            transforms.ToTensor(),
            ])
    image = Transform(image)   
    image = image.unsqueeze(0)
    
    return image.to(device)

def predict(image, model, file, log):
    file = file
    image = prepare_image(image)
    
    with torch.no_grad():
        preds = model(image)
    score = preds.item()
    
    with open(log,'a') as f:
        f.write(f'\n{file},{round(score,2)}')
    f.close()
    
def process(x, y, log):
    path = x
    file = y
    image_path = path + file
    #print(f'{file}')
    image = Image.open(image_path)
    model = torchvision.models.resnet50()
    # model.avgpool = nn.AdaptiveAvgPool2d(1) # for any size of the input
    model.fc = torch.nn.Linear(in_features=2048, out_features=1)
    model.load_state_dict(torch.load('model/model-resnet50.pth', map_location=device)) 
    model.eval().to(device)
    predict(image, model, image_path, log)

# %% [markdown]
# # Analyze folder of pictures

# %%
image_location = '../datasets/photocentric/'
log = 'images.log'

with open(log,'w') as f:
    f.write('image,score')
f.close()

list_of_files = os.listdir(image_location)
count = 0

# TQDM is used as a progress bar for image processing
from tqdm import tqdm
import time

count = 0
for i in tqdm(list_of_files):
    process(image_location,list_of_files[count],log)
    count +=1
# Out:
# 100%|██████████| 189/189 [04:56<00:00,  1.55s/it]

# %% [markdown]
# # Pandas DataFrame for Image Analysis

# %%
import pandas as pd

# %%
df = pd.read_csv('images.log')

# %%
df.head()
# Out:
#                                            image  score
# 0          ../datasets/photocentric/IMG_8624.jpg   5.06
# 1  ../datasets/photocentric/598993211.464769.jpg   3.62
# 2          ../datasets/photocentric/IMG_8694.jpg   2.61
# 3          ../datasets/photocentric/IMG_8777.jpg   2.82
# 4          ../datasets/photocentric/IMG_8702.jpg   2.90

# %%
df.sort_values(by=['score'], ascending=False, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#                                    image  score
# 0  ../datasets/photocentric/IMG_8738.jpg   5.81
# 1  ../datasets/photocentric/IMG_8646.jpg   5.62
# 2  ../datasets/photocentric/IMG_8650.jpg   5.61
# 3  ../datasets/photocentric/IMG_8648.jpg   5.57
# 4  ../datasets/photocentric/IMG_8652.jpg   5.55

# %%
print('Highest scored photo')
from IPython.display import Image
Image(filename=df['image'][0])
# Out:
# Highest scored photo

# %% [markdown]
# # Facial Recognition

# %%
from PIL import Image
import face_recognition
import numpy as np

# %%
sample_image = df['image'][0]
image = face_recognition.load_image_file(sample_image)

face_landmarks_list = face_recognition.face_landmarks(image)

# %%
pil_image = Image.fromarray(image)
pil_image.show()

# %% [markdown]
# # EXIF Data for more EDA

# %%
# Create a dataframe of exif data from the top 10 photos and the low 10 photos for analysis

# %% [markdown]
# # Facial Recognition

# %%
# use opencv for facial recognition and measuring attractiveness
# Find my pictures

# %% [markdown]
# # Background Object Classification

# %%
# Detect background sponsors

# %% [markdown]
# # Location Recognition

# %%
# Detect location of image through either exif or background image
